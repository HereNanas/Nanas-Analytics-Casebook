# %%
import pandas as pd
dt = pd.read_csv('28.csv')

dt.head()
# Out:
#    Rank     Sourceid                                  Title     Type  \
# 0     1        28773     Ca-A Cancer Journal for Clinicians  journal
# 1     2        19434       MMWR Recommendations and Reports  journal
# 2     3        20315  Nature Reviews Molecular Cell Biology  journal
# 3     4        29431         Quarterly Journal of Economics  journal
# 4     5  21100812243               Nature Reviews Materials  journal
#
#                  Issn     SJR SJR Best Quartile  H index  Total Docs. (2020)  \
# 0  15424863, 00079235  62,937                Q1      168                  47
# 1  10575987, 15458601  40,949                Q1      143                  10
# 2  14710072, 14710080  37,461                Q1      431                 115
# 3  00335533, 15314650  34,573                Q1      259                  40
# 4            20588437  32,011                Q1      108                  92
#
#    Total Docs. (3years)  Total Refs.  Total Cites (3years)  \
# 0                   119         3452                 15499
# 1                     9         1292                   492
# 2                   338         8439                 10844
# 3                   110         2733                  1945
# 4                   264        10632                 11188
#
#    Citable Docs. (3years)  Cites / Doc. (2years)  Ref. / Doc.         Country  \
# 0                      80                 126.34        73.45   United States
# 1                       9                  50.00       129.20   United States
# 2                     167                  32.83        73.38  United Kingdom
# 3                     109                  16.00        68.33  United Kingdom
# 4                     138                  32.15       115.57  United Kingdom
#
#              Region                                         Publisher  \
# 0  Northern America                                   Wiley-Blackwell
# 1  Northern America  Centers for Disease Control and Prevention (CDC)
# 2    Western Europe                           Nature Publishing Group
# 3    Western Europe                           Oxford University Press
# 4    Western Europe                           Nature Publishing Group
#
#     Coverage                                         Categories
# 0  1950-2020                     Hematology (Q1); Oncology (Q1)
# 1  1990-2020  Epidemiology (Q1); Health Information Manageme...
# 2  2000-2020          Cell Biology (Q1); Molecular Biology (Q1)
# 3  1886-2020                    Economics and Econometrics (Q1)
# 4  2016-2020  Biomaterials (Q1); Electronic, Optical and Mag...

# %%
dt.isnull().sum()
# Out:
# Rank                        0
# Sourceid                    0
# Title                       0
# Type                        0
# Issn                        0
# SJR                         0
# SJR Best Quartile           0
# H index                     0
# Total Docs. (2020)          0
# Total Docs. (3years)        0
# Total Refs.                 0
# Total Cites (3years)        0
# Citable Docs. (3years)      0
# Cites / Doc. (2years)       0
# Ref. / Doc.                 0
# Country                     0
# Region                      0
# Publisher                 269
# Coverage                    0
# Categories                  0
# dtype: int64

# %%
import numpy as np

def clean_dataset(dt):
    assert isinstance(dt, pd.DataFrame), "dt needs to be a pd.DataFrame"
    dt.dropna(inplace=True)
    indices_to_keep = ~dt.isin([np.nan, np.inf, -np.inf]).any(1)
    return dt[indices_to_keep].astype(np.float64)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

# %%
#attribut selection
X = dt.iloc[:,[7, 8, 9, 10, 11, 12, 13, 14]].values
y = dt.iloc[:,6].values

# %%
from sklearn.preprocessing import StandardScaler
X = StandardScaler().fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, stratify=y, random_state=10)

scaler = StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
#define cross-validation method to use
cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

# %%
dtc = DecisionTreeClassifier
model1 = AdaBoostClassifier(estimator=dtc(max_depth=1000), n_estimators=500, random_state=0)

model1.fit(X_train, y_train)
y_pred = model1.predict(X_test)

# %%
from sklearn.pipeline import Pipeline
pipe = Pipeline([('scaler', StandardScaler()), ('model', model1)])
result = cross_val_score(pipe, X, y, cv=cv)

# %%
print(result)
# Out:
# [0.52081665 0.52401922 0.51841473 0.50720576 0.51160929 0.51801441
#  0.5256205  0.52201761 0.5154185  0.54104926]

# %%
#from sklearn import model_selection
#result= model_selection.cross_val_score(model1,X, y, cv=cv)

# %%
result.mean()
# Out:
# np.float64(0.5204185935853208)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[1413,  554,  223,   84],
#        [ 526,  770,  450,  177],
#        [ 187,  403,  761,  398],
#        [  67,  173,  375,  933]])

# %%
from sklearn.metrics import classification_report
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n          Q1       0.64      0.62      0.63      2274\n          Q2       0.41      0.40      0.40      1923\n          Q3       0.42      0.44      0.43      1749\n          Q4       0.59      0.60      0.59      1548\n\n    accuracy                           0.52      7494\n   macro avg       0.51      0.51      0.51      7494\nweighted avg       0.52      0.52      0.52      7494\n'

# %%
from sklearn.metrics import classification_report
report = classification_report(y_test, y_pred, output_dict=True)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5173472111022152

# %%
precision = report['macro avg']['precision']
recall = report['macro avg']['recall']

print(precision)
print(recall)
# Out:
# 0.5140789213607289
# 0.5149017503314812

# %%
f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt=".0f", ax=ax)
plt.xlabel("y_head")
plt.ylabel("y_true")
plt.show()

# %%
# !pip install yellowbrick
# Out:
# Requirement already satisfied: yellowbrick in /usr/local/lib/python3.12/dist-packages (1.5)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from yellowbrick) (3.10.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from yellowbrick) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from yellowbrick) (1.6.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from yellowbrick) (2.0.2)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from yellowbrick) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->yellowbrick) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->yellowbrick) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.17.0)

# %%
from yellowbrick.classifier.rocauc import roc_auc
roc_auc(model1, X_train, y_train, X_test=X_test, y_test=y_test)
plt.savefig('roc_auc.png')
